# %%
import hail as hl
hl.init()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ef0cd149-33a0-465e-9878-e93f1c042be7">Loading BokehJS ...</span>
#     </div>
# 24/07/22 14:04:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Running on Apache Spark version 3.3.3
# SparkUI available at http://wm708-091.broadinstitute.org:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.128-eead8100a1c1
# ...

# %%
ht = hl.read_table('gs://seqr-hail-search-data/v03/GRCh38/SNV_INDEL/families/F019734_bon_uc499.ht')

# %%
ht.describe()
# Out:
# ----------------------------------------
# Global fields:
#     'sample_ids': array<str>
#     'sample_type': str
#     'updates': set<str>
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'filters': set<str>
#     'entries': array<struct {
#         GQ: int32,
#         AB: float32,
#         DP: int32,
#         GT: call
#     }>
# ----------------------------------------
# Key: ['locus', 'alleles']
# ----------------------------------------

# %%
ht.show()
# Out:
# <StructExpression of type struct{locus: str, alleles: str, filters: str, entries: str}>
# [Stage 0:>                                                          (0 + 1) / 1]
# +---------------+------------+---------------------------------+
# | locus         | alleles    | filters                         |
# +---------------+------------+---------------------------------+
# | locus<GRCh38> | array<str> | set<str>                        |
# +---------------+------------+---------------------------------+
# | chr1:12719    | ["G","C"]  | {"VQSRTrancheSNP99.70to99.80"}  |
# | chr1:12807    | ["C","T"]  | {"VQSRTrancheSNP99.70to99.80"}  |
# | chr1:13079    | ["C","G"]  | {"VQSRTrancheSNP99.90to99.95"}  |
# | chr1:13418    | ["G","A"]  | {"VQSRTrancheSNP99.95to100.00"} |
# | chr1:13613    | ["T","A"]  | {"VQSRTrancheSNP99.95to100.00"} |
# | chr1:13684    | ["C","T"]  | {"VQSRTrancheSNP99.95to100.00"} |
# | chr1:13813    | ["T","G"]  | {"ExcessHet"}                   |
# ...

# %%
ht.globals.collect()
# Out:
# <StructExpression of type struct{__uid_3: struct{sample_ids: array<str>, sample_type: str, updates: set<str>}}>
# [Struct(sample_ids=['BON_UC499_1_1', 'BON_UC499_3_1', 'BON_UC499_4_1'], sample_type='WES', updates={'gs://fc-63ed451e-5156-4c2c-95e7-87b829f7a288/RDG_Broad_WES_Internal_Oct2023/part_one_outputs/chr*/RDG_Broad_WES_Internal_chr*.*.hard_filtered_with_genotypes.vcf.gz'})]
