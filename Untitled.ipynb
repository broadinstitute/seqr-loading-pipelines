# %%
import hail as hl
hl.init()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="eb5888c1-1fd8-4039-a2c8-db5703b6c27c">Loading BokehJS ...</span>
#     </div>
# 24/11/15 15:58:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Running on Apache Spark version 3.3.4
# SparkUI available at http://10.116.9.133:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.130-bea04d9c79b5
# ...

# %%
ht = hl.import_table(
'gs://gcp-public-data--gnomad/release/3.1/secondary_analyses/genomic_constraint/constraint_z_enh_gene_roadmaplinks.all.download.txt.gz',
force_bgz=True
)

# %%
ht.show()
# Out:
# +-------------+---------+-------------+-------------+
# | tissue      | chrom   | start       | end         |
# +-------------+---------+-------------+-------------+
# | str         | str     | str         | str         |
# +-------------+---------+-------------+-------------+
# | "ESC"       | "chr19" | "58841800"  | "58842400"  |
# | "ESC"       | "chr10" | "52616800"  | "52618000"  |
# | "ESC"       | "chr12" | "9218400"   | "9218600"   |
# | "ESC"       | "chr12" | "8973400"   | "8974400"   |
# | "ESC"       | "chr22" | "43093800"  | "43094600"  |
# | "PLACENTA"  | "chr22" | "43093800"  | "43094600"  |
# | "ESC"       | "chr3"  | "151533600" | "151534200" |
# | "Sm_Muscle" | "chr3"  | "151533600" | "151534200" |
# | "ESC"       | "chr1"  | "12688400"  | "12689600"  |
# | "iPSC"      | "chr1"  | "12688400"  | "12689600"  |
# +-------------+---------+-------------+-------------+
#
# +----------------------------+-----------+-------------------+
# ...

# %%
ht = hl.read_table('gs://seqr-reference-data/GRCh38/gnomad_nc_constraint/gnomad_non-coding_constraint_z_scores.ht')
ht.count()
# Out:
# 2042629

# %%
ht.count()
# Out:
# 2042629

# %%
ht.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'interval': interval<locus<GRCh38>>
#     'target': float64
# ----------------------------------------
# Key: ['interval']
# ----------------------------------------

# %%
from enum import Enum


class ReferenceGenome(str, Enum):
    GRCh37 = 'GRCh37'
    GRCh38 = 'GRCh38'


def get_ht(raw_dataset_path: str, reference_genome: ReferenceGenome) -> hl.Table:
    ht = hl.import_table(
        raw_dataset_path,
        force_bgz=True,
        types={'z': hl.tfloat32},
    )
    ht.show()
    print(ht.count())
    ht = ht.select(
        interval=hl.parse_locus_interval(
            hl.str('').join([ht.chrom, ':', ht.start, '-', ht.end]),
            reference_genome=reference_genome.value,
            invalid_missing=True
        ),
        z_score=ht.z,
    )
    return ht.key_by('interval')

# %%
ht = get_ht(
    'gs://gcp-public-data--gnomad/release/3.1/secondary_analyses/genomic_constraint/constraint_z_genome_1kb.raw.download.txt.gz',
    ReferenceGenome.GRCh38
)
# Out:
# +--------+----------+----------+----------------------+----------+
# | chrom  | start    | end      | element_id           | possible |
# +--------+----------+----------+----------------------+----------+
# | str    | str      | str      | str                  | str      |
# +--------+----------+----------+----------------------+----------+
# | "chr1" | "54000"  | "55000"  | "chr1-54000-55000"   | "52.0"   |
# | "chr1" | "61000"  | "62000"  | "chr1-61000-62000"   | "276.0"  |
# | "chr1" | "98000"  | "99000"  | "chr1-98000-99000"   | "5.0"    |
# | "chr1" | "99000"  | "100000" | "chr1-99000-100000"  | "8.0"    |
# | "chr1" | "104000" | "105000" | "chr1-104000-105000" | "2.0"    |
# | "chr1" | "108000" | "109000" | "chr1-108000-109000" | "134.0"  |
# | "chr1" | "109000" | "110000" | "chr1-109000-110000" | "24.0"   |
# | "chr1" | "133000" | "134000" | "chr1-133000-134000" | "2.0"    |
# | "chr1" | "135000" | "136000" | "chr1-135000-136000" | "4.0"    |
# ...

# %%
ht.show()
# Out:
# [Stage 26:>                                                         (0 + 1) / 1]
# +---------------------------+----------+
# | interval                  |  z_score |
# +---------------------------+----------+
# | interval<locus<GRCh38>>   |  float32 |
# +---------------------------+----------+
# | [chr1:802400-chr1:802600) | 1.51e+00 |
# | [chr1:858600-chr1:858800) | 1.58e+00 |
# | [chr1:858600-chr1:858800) | 1.58e+00 |
# | [chr1:858600-chr1:858800) | 1.58e+00 |
# | [chr1:858600-chr1:858800) | 1.58e+00 |
# | [chr1:858600-chr1:858800) | 1.58e+00 |
# | [chr1:858600-chr1:858800) | 1.58e+00 |
# | [chr1:858600-chr1:858800) | 1.58e+00 |
# | [chr1:867020-chr1:867220) | 1.51e+00 |
# | [chr1:910600-chr1:911200) | 6.44e-01 |
# +---------------------------+----------+
# showing top 10 rows

# %%
ht.count()
# Out:
# [Stage 27:>                                                         (0 + 1) / 1]
# 228563

# %%
228563-2042629
